# %%
2+2
# Out:
# 4

# %% [markdown]
# ![CantorLogo.png](attachment:CantorLogo.png)
# ![CantorLogo.png](attachment:CantorLogo.png)

# %% [markdown]
# ![CantorLogo.png](attachment:CantorLogo.png)
